# %% [markdown]
# # Prepare word2vec

# %%
import word2vec, sys, os, math
import pickle as pkl
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
word2vec_bin_loc = '/media/mrmad/283d233c-d7d8-4bd6-830b-25f7c7a665f0/mrmad/Documents/Essex/Thesis/vivan/Neuro_Agent_FInal/scholar/untagged_wikipedia_for_word2vec.bin'

# %%
def load_word2vec(model_filename):
    model = word2vec.load(model_filename)
    return model

# %%
word_vectors = load_word2vec(word2vec_bin_loc)

# %%
# check if works
word_vectors['trump']
# Out:
# array([ 0.01308811, -0.07988005,  0.10500788,  0.07100031, -0.07165847,
#         0.11938906,  0.0280553 ,  0.14792797,  0.23113307,  0.01723865,
#         0.03450589, -0.07995256, -0.05783403,  0.03983924, -0.1888995 ,
#        -0.09949619, -0.03393186,  0.11679307,  0.18283083,  0.08827897,
#         0.03169184,  0.01546468,  0.1338411 , -0.02819854, -0.01757766,
#        -0.04990632,  0.1517567 , -0.11641905, -0.00338179,  0.02553399,
#        -0.02359519, -0.12224154, -0.04414155, -0.02390066, -0.08413405,
#         0.0203083 ,  0.07319663,  0.08502512,  0.1577934 , -0.12009872,
#        -0.01799029, -0.01995073,  0.26017562, -0.12101247,  0.00133403,
#         0.03656866, -0.13598526, -0.22576216, -0.04886628,  0.01520873,
#         0.03005804, -0.03202747, -0.01397827, -0.09020092, -0.03266959,
#         0.19127548, -0.20276776, -0.08222742,  0.05252043,  0.01709458,
#         0.00267752,  0.06112841,  0.10025077, -0.00340389,  0.06422501,
#        -0.11270928, -0.08901594,  0.14634514,  0.10648733, -0.03628331,
#        -0.00622026,  0.08119574, -0.04528693, -0.08975697,  0.06455193,
#         0.16379918,  0.19530585,  0.09023827,  0.08885857,  0.00406857,
#         0.0871474 ,  0.15461725, -0.17560525,  0.14635909, -0.09971964,
#        -0.04637906,  0.08775022,  0.12554881,  0.00968442, -0.09577707,
#        -0.07186738,  0.00614042, -0.03626469, -0.10655725, -0.04052123,
#        -0.16856039,  0.0544019 , -0.04959534, -0.07065991,  0.11518459])

# %% [markdown]
# # TRY NEW METHOD . it works
# from https://www.kaggle.com/jeffd23/visualizing-word-vectors-with-t-sne/notebook

# %% [markdown]
# # Function to plot the words in TSNE

# %%
def tsne_plot(tokens,labels,name):
    "Creates and TSNE model and plots it"  
    #tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
    tsne_model = TSNE(perplexity=40, n_components=2, n_iter=4000)
    new_values = tsne_model.fit_transform(tokens)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    plt.figure(figsize=(20, 20)) 
    plt.axis([-8,8,-9,8])
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.savefig(name, bbox_inches = 'tight')
    plt.show()

# %% [markdown]
# # 1) Function to plot the words seen before the game

# %% [markdown]
# # The words seen during the games are in:
#
# # Lets use run_2

# %%
with open('./finalruns/run_2/words_seen_omniquest_pop50gen500_220818.pkl', 'rb') as i:
    x = pkl.load(i)

# %%
len(x)
# Out:
# 162

# %%
before_labels = []
before_tokens = []

for y in x:
    label = x[y]
    before_tokens.append(word_vectors.vectors[label])
    before_labels.append(word_vectors.vocab[label])

# %%
arr = [str(r) for r in before_labels]
print(arr)
# Out:
# ['with', 'also', 'rationale', 'fc', 'the', 'health', 'population', 'century', 'prix', 'foreign', 'logs', 'pass', 'again.', 'school', 'ez', 'i', 'income', 'subsided', 'sources', 'along', 'show', 'coaches', 'doesn', 'contract', 'none', 'cookie', 'x', 'should', 'by', 'lianna', 'father', 'wagon', 'non', 'be', 'other', 'stars', 'nine', 'lane', 'coat', 'veterans', 'three', 'like', 'colorado', 'page', 'registered', 'spedding', 'were', 'decision', 'dst', 'oka', 'related', 'sky', 'feels', 'hispanic', 'versus', 'continued', 'given', 'railways', 'annual', 'public', 'cd', 'unrecognized', 'article', 'partemental', 'storm', 's', 'royal', 'esq.', 'monster', 'an', 'control', 'interested', 'how', 'bishop', 'niweh', 'that', 'wickets', 'hamburg', 'over', 'partner', 'and', 'has', 'case', 'night', 'total', 'called', 'this', 'newly', 'mexico', 'william', 'manuel', 'download', 'song', 'visual', 'of', 'female', 'pressure', 'michaud', 'it.', 'in', 'baptism', 'exception.', 'liverpool', 'content', 'for', 'proposed', 'played', 'positive', 'modify', 'services.', 'onh', 'escape', 'typo', 'beatings', 'utc', 'fox', 'unremitting', 'ended', 'score', 'association.', 'test', 'jack', 'bin', 'clubnat', 'ponies', 'nailmaking', 'rieure', 'close', 'to', 'development.', 'prime', 'evans', 'see', 'refseqprotein', 'one', 'seems', 'hat', 'family', 'killed', 'future', 'uintas', 'gendarmes', 'elisha', 'found', 'directors', 'your', 'captures', 'romano', 'race', 'institute', 'pital', 'players', 'list', 'under', 'goblin', 'forum.', 'collection', 'mom', 'electromagnetic', 'people', 'aise', 'or']

# %%
len(before_tokens)
# Out:
# 162

# %%
name1 = 'TSNE plot of word embeddings at the start of game.png'
tsne_plot(before_tokens,before_labels,name1)

# %% [markdown]
# # 2) The plot of words seen during the games at counter 100:

# %%
with open('./finalruns/run_2/saved_pickles/test_word_seen_vectors_at_100_.pkl', 'rb') as f:
    tokens_during_100 = pkl.load(f)

# %%
tokens_during_100[:1]
# Out:
# [array([-0.9999994 ,  0.99975902, -1.        ,  1.        ,  0.75122952,
#          1.        , -1.        ,  0.99988675,  1.        , -1.        ,
#          0.99882984,  0.98683804,  1.        , -0.9999159 ,  1.        ,
#          0.0524145 ,  1.        ,  1.        , -1.        , -0.97725451,
#         -1.        ,  0.96938396, -1.        ,  0.99999505, -0.99999666,
#          1.        , -1.        , -0.99975342, -1.        ,  0.99998504,
#          1.        , -1.        , -1.        ,  1.        , -1.        ,
#         -0.97509015,  0.99565995,  1.        , -0.99999928,  0.86223936,
#         -0.81566858,  1.        ,  0.74260038,  1.        ,  0.98042756,
#         -0.99371761, -1.        , -1.        , -1.        ,  0.99662232,
#         -1.        ,  0.6348362 , -0.99954194,  1.        ,  1.        ,
#          0.99999058,  1.        , -1.        ,  1.        , -0.80486053,
#         -1.        , -1.        , -1.        ,  1.        ,  1.        ,
#          0.99999881, -1.        ,  0.9868921 ,  0.89133453, -0.99999952,
#          1.        , -0.99995798, -0.99999803,  0.99902916,  0.42557275,
#          1.        ,  0.99999988, -1.        ,  1.        , -0.99987578,
#          0.99999845, -0.54640365,  1.        , -0.99997669, -1.        ,
#         -0.63925046, -1.        , -0.70457649,  0.99993873,  1.        ,
#         -0.9075042 ,  1.        , -1.        , -1.        ,  0.99980074,
#          1.        ,  0.97737509,  0.99779373,  1.        ,  0.99530387])]

# %%
with open('./finalruns/run_2/saved_pickles/test_word_seen_vocabs_at_100_.pkl', 'rb') as g:
    labels_during_100 = pkl.load(g)

# %%
labels_during_100[:2]
# Out:
# ['has_VBZ', 'sections_NNS']

# %%
# remove tag comments
labels_during_100_clean = [] 

for r in labels_during_100:
    labels_during_100_clean.append(r.split('_')[0])

# %%
len(labels_during_100_clean)
# Out:
# 104

# %%
print(labels_during_100_clean)
# Out:
# ['has', 'sections', 'the', 'since', 'river', 'looks', 'these', 'riverbed', 'various', 'south', 'path', 'forest', 'cuts', 'west', 'some', 'by', 'go', 'passages', 'this', 'that', 'shovel', 'in', 'dry', 'passage', 'is', 'like', 'meandering', 'standing', 'separate', 'sandy', 'southeast', 'branches', 'leading', 'came', 'surrounded', 'beach', 'here', 'tree', 'goes', 'there', 'west', 'apparently', 'into', 'worn', 'are', 'long', 'north', 'large', 'smaller', 'northwest', 'canyon', 'while', 'brief', 'a', 'course', 'small', 'an', 'gone', 'nothing', 'rock', 'continue', 'entrance', 'formed', 'see', 'snorkel', 'lead', 'two', 'forming', 'east', 'rather', 'back', 'rocky', 'dense', 'carrying', 'clearing', 'can', 'you', 'paths', 'larger', 'territory', 'narrow', 'cut', 'and', 'large', 'appears', 'to', 'around', 'of', 'east', 'gap', 'ancient', 'around', 'widening', 'north', 'way', 'winding', 'seems', 'boulders', 'several', 'being', 'what', 'that', 'clearing', 'boulder']

# %%
name2 = 'TSNE plot of word embeddings during the game at generation 100.png'
tsne_plot(tokens_during_100,labels_during_100_clean,name2)

# %% [markdown]
# # 3) The plot of words seen during the games at counter 400:

# %%
with open('./finalruns/run_2/saved_pickles/test_word_seen_vectors_at_400_.pkl', 'rb') as f:
    tokens_during_400 = pkl.load(f)

# %%
tokens_during_400[:1]
# Out:
# [array([-0.02563665, -1.        ,  1.        ,  1.        ,  1.        ,
#          1.        , -1.        ,  1.        ,  1.        ,  0.99506438,
#         -1.        , -1.        , -1.        ,  1.        , -0.48708326,
#          0.99923849,  1.        , -0.99983507,  1.        , -1.        ,
#          1.        ,  1.        , -1.        , -1.        ,  1.        ,
#         -1.        ,  1.        , -0.99539667,  1.        , -1.        ,
#         -0.99986506, -0.94539118,  1.        ,  1.        , -1.        ,
#          0.99932331, -1.        ,  0.9999994 ,  0.80375034, -1.        ,
#          1.        , -1.        ,  1.        ,  0.99999988,  1.        ,
#          0.99832076,  1.        , -1.        ,  1.        , -1.        ,
#          0.89358824, -1.        , -0.99999976,  1.        ,  0.99981666,
#         -1.        , -0.37654564, -1.        ,  1.        ,  1.        ,
#         -1.        , -1.        , -0.99999982, -0.99965405,  1.        ,
#          1.        ,  1.        ,  1.        , -1.        , -1.        ,
#          0.99917835, -1.        ,  1.        ,  1.        ,  0.85241944,
#         -1.        ,  0.25401837,  1.        , -0.9984675 , -1.        ,
#          0.99961996,  0.99999881, -1.        , -0.99999648,  0.99055427,
#          1.        , -1.        , -0.99995703,  1.        , -1.        ,
#         -0.9999994 , -1.        , -1.        , -1.        ,  0.9999997 ,
#         -1.        , -0.99999452,  1.        ,  0.96505338,  1.        ])]

# %%
with open('./finalruns/run_2/saved_pickles/test_word_seen_vocabs_at_400_.pkl', 'rb') as g:
    labels_during_400 = pkl.load(g)

# %%
labels_during_400[:1]
# Out:
# ['deep_JJ']

# %%
# remove tag comments
labels_during_400_clean = [] 

for r in labels_during_400:
    labels_during_400_clean.append(r.split('_')[0])

# %%
print(labels_during_400_clean)
# Out:
# ['deep', 'has', 'sections', 'particularly', 'the', 'coast', 'since', 'river', 'shore', 'room', 'looks', 'features', 'walls', 'these', 'horizon', 'be', 'except', 'riverbed', 'white', 'various', 'south', 'path', 'across', 'prominent', 'forest', 'cuts', 'west', 'some', 'by', 'pitch', 'go', 'passages', 'along', 'this', 'that', 'shovel', 'in', 'dry', 'passage', 'smooth', 'is', 'like', 'ocean', 'meandering', 'standing', 'fastened', 'no', 'for', 'separate', 'towering', 'island', 'ahead', 'sandy', 'southeast', 'branches', 'leading', 'came', 'surrounded', 'beach', 'here', 'tree', 'goes', 'there', 'west', 'apparently', 'see', 'into', 'breathe', 'worn', 'are', 'long', 'north', 'large', 'smaller', 'thing', 'island', 'with', 'northwest', 'canyon', 'while', 'brief', 'a', 'but', 'section', 'course', 'water', 'small', 'an', 'gone', 'nothing', 'rock', 'continue', 'exit', 'out', 'entrance', 'securely', 'formed', 'see', 'snorkel', 'lead', 'two', 'dark', 'looms', 'forming', 'east', 'on', 'rather', 'notable', 'it', 'back', 'rocky', 'dense', 'carrying', 'clearing', 'can', 'stretch', 'lies', 'darkness', 'wall', 'you', 'paths', 'larger', 'territory', 'narrow', 'cut', 'and', 'large', 'winding', 'appears', 'to', 'landmark', 'bit', 'sand', 'about', 'around', 'of', 'east', 'gap', 'main', 'ancient', 'around', 'unclimbable', 'ocean', 'widening', 'north', 'ca', 'way', 'dunes', 'winding', 'seems', 'primary', 'boulders', 'several', 'being', 'what', 'that', 'clearing', 'rest', 'boulder', 'torch', 'cylindrical', 'which']

# %%
len(labels_during_400_clean)
# Out:
# 162

# %%
name3 = 'TSNE plot of word embeddings during the game at generation 400.png'
tsne_plot(tokens_during_400,labels_during_400_clean,name3)

# %% [markdown]
# # 4) The plot of words seen at end of the games are:

# %%
with open('./finalruns/run_2/test_word_seen_vectors_omniquest_pop50gen500_220818.pkl', 'rb') as f:
    tokens_after = pkl.load(f)

# %%
len(tokens_after)
# Out:
# 162

# %%
tokens_after[:1]
# Out:
# [array([-0.02563665, -1.        ,  1.        ,  1.        ,  1.        ,
#          1.        , -1.        ,  1.        ,  1.        ,  0.99506438,
#         -1.        , -1.        , -1.        ,  1.        , -0.48708326,
#          0.99923849,  1.        , -0.99983507,  1.        , -1.        ,
#          1.        ,  1.        , -1.        , -1.        ,  1.        ,
#         -1.        ,  1.        , -0.99539667,  1.        , -1.        ,
#         -0.99986506, -0.94539118,  1.        ,  1.        , -1.        ,
#          0.99932331, -1.        ,  0.9999994 ,  0.80375034, -1.        ,
#          1.        , -1.        ,  1.        ,  0.99999988,  1.        ,
#          0.99832076,  1.        , -1.        ,  1.        , -1.        ,
#          0.89358824, -1.        , -0.99999976,  1.        ,  0.99981666,
#         -1.        , -0.37654564, -1.        ,  1.        ,  1.        ,
#         -1.        , -1.        , -0.99999982, -0.99965405,  1.        ,
#          1.        ,  1.        ,  1.        , -1.        , -1.        ,
#          0.99917835, -1.        ,  1.        ,  1.        ,  0.85241944,
#         -1.        ,  0.25401837,  1.        , -0.9984675 , -1.        ,
#          0.99961996,  0.99999881, -1.        , -0.99999648,  0.99055427,
#          1.        , -1.        , -0.99995703,  1.        , -1.        ,
#         -0.9999994 , -1.        , -1.        , -1.        ,  0.9999997 ,
#         -1.        , -0.99999452,  1.        ,  0.96505338,  1.        ])]

# %%
with open('./finalruns/run_2/test_word_seen_vocab_omniquest_pop50gen500_220818.pkl', 'rb') as g:
    labels_after = pkl.load(g)

# %%
len(labels_after)
# Out:
# 162

# %%
labels_after[:1]
# Out:
# ['deep_JJ']

# %%
# remove tag comments
labels_after_clean = [] 

for r in labels_after:
    labels_after_clean.append(r.split('_')[0])

# %%
print(labels_after_clean)
# Out:
# ['deep', 'has', 'sections', 'particularly', 'the', 'coast', 'since', 'river', 'shore', 'room', 'looks', 'features', 'walls', 'these', 'horizon', 'be', 'except', 'riverbed', 'white', 'various', 'south', 'path', 'across', 'prominent', 'forest', 'cuts', 'west', 'some', 'by', 'pitch', 'go', 'passages', 'along', 'this', 'that', 'shovel', 'in', 'dry', 'passage', 'smooth', 'is', 'like', 'ocean', 'meandering', 'standing', 'fastened', 'no', 'for', 'separate', 'towering', 'island', 'ahead', 'sandy', 'southeast', 'branches', 'leading', 'came', 'surrounded', 'beach', 'here', 'tree', 'goes', 'there', 'west', 'apparently', 'see', 'into', 'breathe', 'worn', 'are', 'long', 'north', 'large', 'smaller', 'thing', 'island', 'with', 'northwest', 'canyon', 'while', 'brief', 'a', 'but', 'section', 'course', 'water', 'small', 'an', 'gone', 'nothing', 'rock', 'continue', 'exit', 'out', 'entrance', 'securely', 'formed', 'see', 'snorkel', 'lead', 'two', 'dark', 'looms', 'forming', 'east', 'on', 'rather', 'notable', 'it', 'back', 'rocky', 'dense', 'carrying', 'clearing', 'can', 'stretch', 'lies', 'darkness', 'wall', 'you', 'paths', 'larger', 'territory', 'narrow', 'cut', 'and', 'large', 'winding', 'appears', 'to', 'landmark', 'bit', 'sand', 'about', 'around', 'of', 'east', 'gap', 'main', 'ancient', 'around', 'unclimbable', 'ocean', 'widening', 'north', 'ca', 'way', 'dunes', 'winding', 'seems', 'primary', 'boulders', 'several', 'being', 'what', 'that', 'clearing', 'rest', 'boulder', 'torch', 'cylindrical', 'which']

# %%
len(labels_after_clean)
# Out:
# 162

# %%
name4 = 'TSNE plot of word embeddings at the end of game.png'
tsne_plot(tokens_after,labels_after_clean,name4)
